# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Imported API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p3219'>
#   <div id="bae7239e-e67a-46ee-a4fd-d8708ccf80ab" data-root-id="p3219" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Loaded the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Displayed data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configured the map plot
city_data_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City",
    hover_cols = ["Max Temp", "Wind Speed", "Cloudiness"]
)

# Displayed the map
city_data_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Max Temp,Wind Speed,Cloudiness)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Filtered data & removed duplicates
city_data = city_data_df.dropna()
city_data = city_data[(city_data_df["Max Temp"]>= 21) & (city_data_df["Max Temp"]<= 28) & (city_data_df["Humidity"]>=50) & (city_data_df["Humidity"]<=65)]
city_data.head()
# Out:
# /var/folders/yk/gw9wr71x4q1fdwjcplr_zc7m0000gn/T/ipykernel_63959/1469509048.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   city_data = city_data[(city_data_df["Max Temp"]>= 21) & (city_data_df["Max Temp"]<= 28) & (city_data_df["Humidity"]>=50) & (city_data_df["Humidity"]<=65)]
#      City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 34        34   naberera  -4.2000   36.9333     21.12        54          94
# 63        63      banda  25.4833   80.3333     24.62        52           0
# 67        67  caravelas -17.7125  -39.2481     26.69        64          94
# 107      107  inhambane -23.8650   35.3833     26.99        65          40
# 152      152    kahului  20.8947 -156.4700     23.80        60           0
#
#      Wind Speed Country        Date
# 34         6.38      TZ  1666108252
# 63         2.68      IN  1666108268
# 67         4.14      BR  1666108272
# 107        5.81      MZ  1666108299
# ...

# %%
# Configured the map plot
preferred_city_map = city_data.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600, 
    size = "Humidity",
    scale = 2,
    color = "City",
    hover_cols = ["Max Temp", "Wind Speed", "Cloudiness"]
)

# Displayed the map
preferred_city_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Max Temp,Wind Speed,Cloudiness)

# %%
# Dropped any rows with null values
city_data = city_data_df.dropna()
# Filtered data based on criteria
city_data = city_data[(city_data_df["Max Temp"]>= 18.33) & (city_data_df["Max Temp"]<= 23.89) & (city_data_df["Humidity"]>=45) & (city_data_df["Humidity"]<=55)]
# Displayed data
city_data
# Out:
# /var/folders/yk/gw9wr71x4q1fdwjcplr_zc7m0000gn/T/ipykernel_63959/867815201.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   city_data = city_data[(city_data_df["Max Temp"]>= 18.33) & (city_data_df["Max Temp"]<= 23.89) & (city_data_df["Humidity"]>=45) & (city_data_df["Humidity"]<=55)]
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 34        34        naberera  -4.2000   36.9333     21.12        54
# 229      229   san cristobal   7.7669  -72.2250     22.10        45
# 284      284        san juan -31.5375  -68.5364     18.64        53
# 305      305         kingman  35.1894 -114.0530     20.07        49
# 363      363          narwar  25.6500   77.9000     22.35        55
# 387      387  ribeira grande  38.5167  -28.7000     19.22        48
# 531      531       chivilcoy -34.8957  -60.0167     22.27        49
#
#      Cloudiness  Wind Speed Country        Date
# 34           94        6.38      TZ  1666108252
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Used the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
details = ["City", "Country","Lat","Lng","Humidity"]
hotel_df = city_data.copy()
hotel_df = hotel_df[details]

# Added an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Displayed  data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 34         naberera      TZ  -4.2000   36.9333        54
# 229   san cristobal      VE   7.7669  -72.2250        45
# 284        san juan      AR -31.5375  -68.5364        53
# 305         kingman      US  35.1894 -114.0530        49
# 363          narwar      IN  25.6500   77.9000        55
# 387  ribeira grande      PT  38.5167  -28.7000        48
# 531       chivilcoy      AR -34.8957  -60.0167        49

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accommodation.hotel"
limit= 20


params = {
    "categories": categories,
    "radius": radius,
    "limit": limit,
    "apiKey":geoapify_key 
}

# Printed a message to follow up the hotel search
print("Starting hotel search")

# Iterated through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = hotel_df.loc[index, "Lng"]
    lat = hotel_df.loc[index, "Lat"]

    # Added the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Converted the API response to JSON format
    name_address = name_address.json()

    # Grabed the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Logged the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Displayed data
hotel_df
# Out:
# Starting hotel search
# naberera - nearest hotel: No hotel found
# san cristobal - nearest hotel: Terra Sur
# san juan - nearest hotel: Hotel San Francisco
# kingman - nearest hotel: Home2 Suites by Hilton Kingman
# narwar - nearest hotel: No hotel found
# ribeira grande - nearest hotel: Hospedaria JSF
# chivilcoy - nearest hotel: Falcone
#                City Country      Lat       Lng  Humidity  \
# 34         naberera      TZ  -4.2000   36.9333        54
# 229   san cristobal      VE   7.7669  -72.2250        45
# 284        san juan      AR -31.5375  -68.5364        53
# 305         kingman      US  35.1894 -114.0530        49
# 363          narwar      IN  25.6500   77.9000        55
# 387  ribeira grande      PT  38.5167  -28.7000        48
# 531       chivilcoy      AR -34.8957  -60.0167        49
#
#                          Hotel Name
# 34                   No hotel found
# 229                       Terra Sur
# 284             Hotel San Francisco
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configured the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600, 
    size = 50,
    scale = 2,
    color = "Hotel Name",
    hover_cols = ["Hotel Name", "Country"]
)

# Displayed the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Hotel Name,Country)
